# %%
import pandas as pd
file_path = 'test.csv'
data = pd.read_csv(file_path, delimiter=';')
print(data.head())
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]>

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4521, step=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_columns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# Apply label encoding to each categorical column
for column in categorical_columns:
    data[column] = label_encoder.fit_transform(data[column])

print(data.head())
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   30   10        1          0        0     1787        0     0        0
# 1   33    7        1          1        0     4789        1     1        0
# 2   35    4        2          2        0     1350        1     0        0
# 3   30    4        1          2        0     1476        1     1        2
# 4   59    1        1          1        0        0        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y  age_le
# 0   19     10        79         1     -1         0         3  0      11
# 1   11      8       220         1    339         4         0  0      14
# 2   16      0       185         1    330         1         0  0      16
# 3    3      6       199         4     -1         0         3  0      11
# 4    5      8       226         1     -1         0         3  0      40

# %%
from sklearn.model_selection import train_test_split
x= data.drop("y", axis=1)
y= data["y"]

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=22, random_state=0)

# %%
x_train.head()
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 3339   34    1        0          1        0        0        0     1        2
# 3044   53    2        1          3        0        7        0     0        0
# 269    56    7        0          1        0     1007        0     0        0
# 1533   32    1        2          1        0     1721        1     0        2
# 3030   53    1        1          1        0       65        0     0        0
#
#       day  month  duration  campaign  pdays  previous  poutcome  age_le
# 3339   21      8       339         1     -1         0         3      15
# 3044   20      9        68         1     -1         0         3      34
# 269    29      5        88         6     -1         0         3      37
# 1533   21      8       650         2     -1         0         3      13
# 3030   28      1        25        18     -1         0         3      34

# %%
x_test.head()
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 4274   35    1        1          0        0      378        1     0        2
# 72     31    4        2          2        0     6248        1     0        2
# 1065   30   10        1          2        0        0        1     0        0
# 3185   42    0        1          1        0      529        1     1        0
# 130    41    1        1          0        0      168        1     0        0
#
#       day  month  duration  campaign  pdays  previous  poutcome  age_le
# 4274   16      8       427         3     -1         0         3      16
# 72      9      8       154         2     -1         0         3      12
# 1065   18      9       756         1     -1         0         3      11
# 3185   19      9       193         3     -1         0         3      23
# 130    18      9       187         3     -1         0         3      22

# %%
from sklearn.tree import DecisionTreeClassifier
clf= DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred= clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score

# %%
accuracy= accuracy_score(y_test, y_pred)
print("accuracy is :",accuracy)
# Out:
# accuracy is : 0.8181818181818182

# %%
report= classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        19
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.82        22
#    macro avg       0.43      0.47      0.45        22
# weighted avg       0.74      0.82      0.78        22
